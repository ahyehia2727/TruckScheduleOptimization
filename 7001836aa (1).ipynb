# %%
import numpy as np
import random
import math
import copy

# Task 1: Generate 40 trucks with capacity between 500 to 1000Kg
trucks_capacity = np.random.randint(500, 1001, size=40)

# Task 2: Generate 120 packages with weight (between 200-1000) and distance (between 20 to 100)
packages = np.random.randint(200, 951, size=(120, 2))
packages[:, 1] = np.random.randint(20, 101, size=120)

# Task 3: Initial assignment
def initial_assignment(trucks_capacity, packages):
    assignments = np.full((40, 3, 3), -1, dtype=int)

    package_assigned = np.zeros(len(packages), dtype=bool)
    for t_idx, capacity in enumerate(trucks_capacity):
        for trip in range(3):  # A truck can make 3 trips
            remaining_capacity = capacity
            for i in range(3):  # A truck can carry up to 3 packages per trip
                # Find packages that can be carried by the current truck and are not yet assigned
                available_packages = np.argwhere((packages[:, 0] <= remaining_capacity) & (~package_assigned)).flatten()
                if len(available_packages) > 0:
                    p_idx = np.random.choice(available_packages)
                    assignments[t_idx][trip][i] = p_idx
                    package_assigned[p_idx] = True
                    remaining_capacity -= packages[p_idx][0]
                else:
                    break

    return assignments, package_assigned

# Task 4: Calculate the cost
def calculate_cost(assignments, initial_capacity, packages):
    cost = 0
    delivered_packages = np.zeros(len(packages), dtype=bool)
    for t_idx, trips in enumerate(assignments):
        for trip in trips:
            for p_idx in trip:
                if p_idx != -1:
                    p = packages[p_idx]
                    cost += (initial_capacity[t_idx] - p[0]) / p[1]
                    delivered_packages[p_idx] = True

    # Add penalty for undelivered packages
    penalty = 100 * np.sum(np.logical_not(delivered_packages))
    cost += penalty

    return cost, delivered_packages

# Task 5 and 6: Use SGA optimization
def optimization(assignments, trucks_capacity, packages, initial_cost, max_iter=7500, tol=0.5):
    initial_capacity = trucks_capacity.copy()
    current_cost = initial_cost
    current_assignments = copy.deepcopy(assignments)

    for iteration in range(max_iter):
        # Swap two random packages
        t1, t2 = random.sample(range(40), 2)
        trip1, trip2 = random.sample(range(3), 2)
        p1, p2 = random.sample(range(3), 2)
        new_assignments = copy.deepcopy(current_assignments)
        new_assignments[t1][trip1][p1], new_assignments[t2][trip2][p2] = new_assignments[t2][trip2][p2], new_assignments[t1][trip1][p1]

        # Check if the swap exceeds the truck capacity
        new_assigned_weights_t1 = [packages[p_idx][0] if p_idx != -1 else 0 for p_idx in new_assignments[t1][trip1]]
        new_assigned_weights_t2 = [packages[p_idx][0] if p_idx != -1 else 0 for p_idx in new_assignments[t2][trip2]]
        if sum(new_assigned_weights_t1) > initial_capacity[t1] or sum(new_assigned_weights_t2) > initial_capacity[t2]:
            continue

        # Calculate new cost
        new_cost, delivered_packages = calculate_cost(new_assignments, initial_capacity, packages)

        # Check if the cost is better
        if new_cost < current_cost:
            print(f"Iteration {iteration}: Switched package {p1+1} of truck {t1+1} trip {trip1+1} with package {p2+1} of truck {t2+1} trip {trip2+1}, old cost: {current_cost}, new cost: {new_cost}")
            # Check for convergence
            if abs(new_cost - current_cost) < tol and np.all(delivered_packages):
                break
            current_assignments, current_cost = new_assignments, new_cost

        # Assign unassigned packages
        unassigned_packages = np.argwhere(delivered_packages == False).flatten()
        for p_idx in unassigned_packages:
            p_weight = packages[p_idx][0]
            available_trucks = np.argwhere(initial_capacity >= p_weight).flatten()
            if len(available_trucks) > 0:
                for t_idx in available_trucks:
                    for trip in range(3):
                        assigned_package_weights = [packages[p_idx][0] if p_idx != -1 else 0 for p_idx in current_assignments[t_idx][trip]]
                        if sum(assigned_package_weights) + p_weight <= initial_capacity[t_idx]:
                            for i, delivery in enumerate(current_assignments[t_idx][trip]):
                                if delivery == -1:
                                    current_assignments[t_idx][trip][i] = p_idx
                                    delivered_packages[p_idx] = True

                                    # Recalculate the cost after assigning the package
                                    current_cost, _ = calculate_cost(current_assignments, initial_capacity, packages)
                                    break
                            if delivered_packages[p_idx]:
                                break

    return current_assignments, current_cost, initial_capacity

def print_optimized_assignments(assignments, initial_capacity, packages):
    for t, trips in enumerate(assignments):
        print(f"Truck {t}:")
        i=1
        for trip_idx, trip in enumerate(trips):
            trip_package_weights = [packages[p][0] for p in trip if p != -1]
            if len(trip_package_weights) == 0:
                continue
            truck_capacity = initial_capacity[t]
            print(f"  Trip {i}: weight = {truck_capacity}, package weights = {trip_package_weights}")
            i+=1


# Run the optimization
assignments, remaining_capacity = initial_assignment(trucks_capacity, packages)
initial_cost, _ = calculate_cost(assignments, trucks_capacity, packages)
print("Initial cost:", initial_cost)

optimized_assignments, optimized_cost, initial_capacity = optimization(assignments, trucks_capacity, packages, initial_cost)
print("Optimized cost:", optimized_cost)

# Print truck deliveries
print("\nTruck deliveries after optimization:")

print_optimized_assignments(optimized_assignments, initial_capacity, packages)

# Find and print unassigned packages' weights
_, delivered_packages = calculate_cost(optimized_assignments, initial_capacity, packages)
unassigned_packages = np.argwhere(delivered_packages == False).flatten()
unassigned_weights = [packages[p_idx][0] for p_idx in unassigned_packages]
print("\nUnassigned packages' weights:", unassigned_weights)
# Out:
# Initial cost: 1240.881162696105
# Iteration 3: Switched package 3 of truck 3 trip 2 with package 2 of truck 37 trip 1, old cost: 1240.881162696105, new cost: 1239.193662696105
# Iteration 6: Switched package 2 of truck 29 trip 2 with package 1 of truck 6 trip 1, old cost: 1239.193662696105, new cost: 1238.5013550037972
# Iteration 54: Switched package 3 of truck 31 trip 1 with package 1 of truck 5 trip 3, old cost: 1238.5013550037972, new cost: 1235.8527063551487
# Iteration 57: Switched package 1 of truck 5 trip 2 with package 3 of truck 37 trip 3, old cost: 1235.8527063551487, new cost: 1234.1027063551487
# Iteration 92: Switched package 1 of truck 8 trip 1 with package 2 of truck 39 trip 3, old cost: 1234.1027063551487, new cost: 1232.1615298845604
# Iteration 104: Switched package 1 of truck 9 trip 1 with package 2 of truck 37 trip 2, old cost: 1232.1615298845604, new cost: 1231.5677798845604
# Iteration 125: Switched package 2 of truck 17 trip 1 with package 1 of truck 38 trip 3, old cost: 1231.5677798845604, new cost: 1229.194645556202
# Iteration 135: Switched package 2 of truck 6 trip 3 with package 3 of truck 39 trip 2, old cost: 1229.194645556202, new cost: 1225.6668677784241
# Iteration 136: Switched package 2 of truck 1 trip 2 with package 3 of truck 5 trip 3, old cost: 1225.6668677784241, new cost: 1221.8486859602426
# Iteration 199: Switched package 3 of truck 26 trip 3 with package 2 of truck 37 trip 1, old cost: 1221.8486859602426, new cost: 1220.5986859602426
# Iteration 214: Switched package 3 of truck 26 trip 3 with package 1 of truck 38 trip 1, old cost: 1220.5986859602426, new cost: 1219.8799359602426
# Iteration 253: Switched package 1 of truck 36 trip 3 with package 3 of truck 39 trip 2, old cost: 1219.8799359602426, new cost: 1219.1299359602426
# Iteration 261: Switched package 1 of truck 17 trip 2 with package 2 of truck 29 trip 3, old cost: 1219.1299359602426, new cost: 1218.7351991181372
# Iteration 273: Switched package 1 of truck 8 trip 2 with package 3 of truck 37 trip 3, old cost: 1218.7351991181372, new cost: 1218.6635616912367
# Iteration 279: Switched package 3 of truck 35 trip 2 with package 2 of truck 7 trip 3, old cost: 1218.6635616912367, new cost: 1216.1702283579034
# Iteration 294: Switched package 1 of truck 17 trip 2 with package 2 of truck 3 trip 1, old cost: 1216.1702283579034, new cost: 1213.4916569293318
# Iteration 301: Switched package 1 of truck 37 trip 1 with package 2 of truck 18 trip 2, old cost: 1213.4916569293318, new cost: 1211.021068694038
# Iteration 317: Switched package 2 of truck 8 trip 3 with package 1 of truck 3 trip 2, old cost: 1211.021068694038, new cost: 1210.003869676839
# Iteration 332: Switched package 1 of truck 7 trip 3 with package 3 of truck 34 trip 2, old cost: 1210.003869676839, new cost: 1207.172544375634
# Iteration 338: Switched package 3 of truck 35 trip 2 with package 2 of truck 38 trip 1, old cost: 1107.1829610423008, new cost: 1104.3429610423009
# Iteration 343: Switched package 1 of truck 16 trip 1 with package 3 of truck 37 trip 3, old cost: 1104.3429610423009, new cost: 1103.861758034782
# Iteration 344: Switched package 3 of truck 37 trip 3 with package 2 of truck 26 trip 1, old cost: 1103.861758034782, new cost: 1100.0522342252582
# Iteration 346: Switched package 1 of truck 39 trip 2 with package 2 of truck 2 trip 3, old cost: 1100.0522342252582, new cost: 1097.452234225258
# Iteration 371: Switched package 1 of truck 10 trip 3 with package 3 of truck 29 trip 1, old cost: 1097.452234225258, new cost: 1096.7379485109725
# Iteration 377: Switched package 1 of truck 1 trip 3 with package 2 of truck 34 trip 1, old cost: 1096.7379485109725, new cost: 1090.4879485109725
# Iteration 390: Switched package 3 of truck 5 trip 3 with package 2 of truck 37 trip 1, old cost: 1090.4879485109725, new cost: 1088.5788576018817
# Iteration 395: Switched package 1 of truck 1 trip 2 with package 3 of truck 34 trip 3, old cost: 1088.5788576018817, new cost: 1086.7495893091987
# Iteration 429: Switched package 3 of truck 36 trip 1 with package 1 of truck 20 trip 3, old cost: 1086.7495893091987, new cost: 1086.1995893091987
# Iteration 456: Switched package 1 of truck 16 trip 1 with package 3 of truck 20 trip 3, old cost: 1086.1995893091987, new cost: 1084.550466502181
# Iteration 468: Switched package 3 of truck 37 trip 3 with package 2 of truck 5 trip 1, old cost: 1084.550466502181, new cost: 1083.742774194489
# Iteration 520: Switched package 2 of truck 15 trip 3 with package 3 of truck 39 trip 1, old cost: 1083.742774194489, new cost: 1083.1094408611555
# Iteration 525: Switched package 1 of truck 25 trip 3 with package 3 of truck 9 trip 1, old cost: 1083.1094408611555, new cost: 1082.7676687092567
# Iteration 558: Switched package 3 of truck 15 trip 3 with package 2 of truck 29 trip 2, old cost: 1082.7676687092567, new cost: 1080.0368994784876
# Iteration 561: Switched package 3 of truck 37 trip 3 with package 2 of truck 27 trip 1, old cost: 1080.0368994784876, new cost: 1079.34459178618
# Iteration 609: Switched package 1 of truck 18 trip 1 with package 2 of truck 5 trip 3, old cost: 1079.34459178618, new cost: 1077.3634597107082
# Iteration 626: Switched package 1 of truck 6 trip 3 with package 3 of truck 38 trip 2, old cost: 1077.3634597107082, new cost: 1074.3009597107082
# Iteration 705: Switched package 1 of truck 21 trip 3 with package 3 of truck 18 trip 1, old cost: 1074.3009597107082, new cost: 1073.5271501868988
# Iteration 783: Switched package 1 of truck 37 trip 1 with package 3 of truck 31 trip 2, old cost: 1073.5271501868988, new cost: 1071.5712678339576
# Iteration 802: Switched package 1 of truck 7 trip 1 with package 3 of truck 21 trip 3, old cost: 1071.5712678339576, new cost: 1070.6799634861313
# Iteration 847: Switched package 2 of truck 1 trip 3 with package 1 of truck 27 trip 1, old cost: 970.9328370493499, new cost: 962.5535267045221
# Iteration 863: Switched package 3 of truck 18 trip 1 with package 1 of truck 35 trip 2, old cost: 962.5535267045221, new cost: 961.5892409902365
# Iteration 866: Switched package 1 of truck 38 trip 1 with package 2 of truck 8 trip 3, old cost: 961.5892409902365, new cost: 960.2323997740202
# Iteration 869: Switched package 2 of truck 26 trip 3 with package 1 of truck 2 trip 2, old cost: 960.2323997740202, new cost: 957.7236278441956
# Iteration 871: Switched package 2 of truck 37 trip 2 with package 1 of truck 8 trip 1, old cost: 957.7236278441956, new cost: 957.6142528441956
# Iteration 875: Switched package 2 of truck 5 trip 2 with package 3 of truck 37 trip 3, old cost: 957.6142528441956, new cost: 954.7506164805593
# Iteration 896: Switched package 1 of truck 30 trip 2 with package 3 of truck 18 trip 1, old cost: 954.7506164805593, new cost: 954.3206164805592
# Iteration 897: Switched package 3 of truck 37 trip 2 with package 1 of truck 2 trip 1, old cost: 954.3206164805592, new cost: 953.6047073896502
# Iteration 916: Switched package 1 of truck 2 trip 3 with package 3 of truck 31 trip 2, old cost: 953.6047073896502, new cost: 946.6870603308266
# Iteration 923: Switched package 2 of truck 4 trip 3 with package 3 of truck 36 trip 2, old cost: 946.6870603308266, new cost: 945.8464806206817
# Iteration 940: Switched package 3 of truck 16 trip 1 with package 1 of truck 11 trip 3, old cost: 945.8464806206817, new cost: 943.5548139540151
# Iteration 949: Switched package 3 of truck 39 trip 1 with package 1 of truck 4 trip 3, old cost: 943.5548139540151, new cost: 943.4119061525967
# Iteration 960: Switched package 3 of truck 31 trip 3 with package 1 of truck 14 trip 1, old cost: 943.4119061525967, new cost: 940.7209970616875
# Iteration 963: Switched package 3 of truck 34 trip 3 with package 2 of truck 29 trip 2, old cost: 940.7209970616875, new cost: 940.2819726714437
# Iteration 995: Switched package 1 of truck 18 trip 2 with package 3 of truck 27 trip 3, old cost: 940.2819726714437, new cost: 934.9962583857293
# Iteration 1059: Switched package 3 of truck 9 trip 1 with package 2 of truck 2 trip 2, old cost: 934.9962583857293, new cost: 934.8127140819319
# Iteration 1139: Switched package 1 of truck 35 trip 3 with package 2 of truck 7 trip 2, old cost: 934.8127140819319, new cost: 928.1341426533604
# Iteration 1178: Switched package 2 of truck 14 trip 1 with package 3 of truck 34 trip 2, old cost: 928.1341426533604, new cost: 927.8449860268545
# Iteration 1192: Switched package 1 of truck 16 trip 3 with package 2 of truck 37 trip 1, old cost: 927.8449860268545, new cost: 927.6631678450362
# Iteration 1202: Switched package 3 of truck 15 trip 3 with package 2 of truck 26 trip 2, old cost: 927.6631678450362, new cost: 927.2016293834979
# Iteration 1259: Switched package 2 of truck 1 trip 2 with package 1 of truck 22 trip 1, old cost: 927.2016293834979, new cost: 924.5816293834978
# Iteration 1389: Switched package 1 of truck 33 trip 2 with package 2 of truck 1 trip 3, old cost: 825.5149627168312, new cost: 823.4661822290263
# Iteration 1439: Switched package 2 of truck 29 trip 2 with package 1 of truck 5 trip 1, old cost: 724.0963192153276, new cost: 724.04880575318
# Iteration 1490: Switched package 3 of truck 9 trip 1 with package 2 of truck 6 trip 3, old cost: 724.04880575318, new cost: 723.7088057531801
# Iteration 1551: Switched package 1 of truck 19 trip 3 with package 3 of truck 18 trip 2, old cost: 723.7088057531801, new cost: 720.4064801717847
# Iteration 1556: Switched package 3 of truck 31 trip 3 with package 1 of truck 4 trip 1, old cost: 621.0829507600199, new cost: 620.5699286469978
# Iteration 1590: Switched package 1 of truck 16 trip 3 with package 3 of truck 39 trip 2, old cost: 620.5699286469978, new cost: 616.8729589500282
# Iteration 1645: Switched package 3 of truck 25 trip 3 with package 1 of truck 35 trip 1, old cost: 616.8729589500282, new cost: 616.139625616695
# Iteration 1671: Switched package 3 of truck 9 trip 1 with package 1 of truck 3 trip 2, old cost: 616.139625616695, new cost: 614.8668983439676
# Iteration 1707: Switched package 3 of truck 29 trip 1 with package 1 of truck 15 trip 3, old cost: 614.8668983439676, new cost: 614.7513468068971
# Iteration 1745: Switched package 3 of truck 39 trip 1 with package 2 of truck 36 trip 2, old cost: 614.7513468068971, new cost: 614.1768787217907
# Iteration 1777: Switched package 2 of truck 34 trip 1 with package 1 of truck 12 trip 2, old cost: 614.1768787217907, new cost: 612.3501243358257
# Iteration 1781: Switched package 3 of truck 36 trip 1 with package 1 of truck 2 trip 3, old cost: 612.3501243358257, new cost: 611.4277713946492
# Iteration 1790: Switched package 1 of truck 25 trip 1 with package 2 of truck 3 trip 2, old cost: 611.4277713946492, new cost: 610.489316571428
# Iteration 1808: Switched package 3 of truck 20 trip 3 with package 1 of truck 12 trip 1, old cost: 610.489316571428, new cost: 610.4780383759394
# Iteration 1841: Switched package 2 of truck 26 trip 1 with package 1 of truck 36 trip 3, old cost: 610.4780383759394, new cost: 609.4264510743519
# Iteration 1881: Switched package 1 of truck 27 trip 1 with package 2 of truck 9 trip 2, old cost: 609.4264510743519, new cost: 608.4170466856373
# Iteration 1897: Switched package 1 of truck 17 trip 1 with package 2 of truck 16 trip 3, old cost: 608.4170466856373, new cost: 608.0306830492736
# Iteration 1921: Switched package 2 of truck 3 trip 2 with package 1 of truck 10 trip 1, old cost: 608.0306830492736, new cost: 608.0134928633071
# Iteration 1977: Switched package 2 of truck 5 trip 3 with package 1 of truck 13 trip 1, old cost: 608.0134928633071, new cost: 608.0112287123636
# Iteration 1978: Switched package 2 of truck 39 trip 1 with package 1 of truck 2 trip 3, old cost: 608.0112287123636, new cost: 606.3212287123637
# Iteration 1985: Switched package 1 of truck 7 trip 2 with package 3 of truck 34 trip 3, old cost: 606.3212287123637, new cost: 603.1878953790304
# Iteration 2025: Switched package 2 of truck 3 trip 2 with package 1 of truck 35 trip 1, old cost: 603.1878953790304, new cost: 602.9286361197711
# Iteration 2034: Switched package 1 of truck 3 trip 1 with package 3 of truck 5 trip 2, old cost: 602.9286361197711, new cost: 602.4598861197711
# Iteration 2089: Switched package 2 of truck 4 trip 3 with package 1 of truck 25 trip 1, old cost: 602.4598861197711, new cost: 597.6322999128745
# Iteration 2161: Switched package 2 of truck 2 trip 2 with package 1 of truck 13 trip 1, old cost: 597.6322999128745, new cost: 597.619880519514
# Iteration 2202: Switched package 2 of truck 6 trip 1 with package 1 of truck 38 trip 3, old cost: 597.619880519514, new cost: 597.5170353702604
# Iteration 2322: Switched package 1 of truck 10 trip 2 with package 3 of truck 9 trip 1, old cost: 597.5170353702604, new cost: 597.5119848652098
# Iteration 2338: Switched package 1 of truck 32 trip 1 with package 2 of truck 1 trip 2, old cost: 597.5119848652098, new cost: 597.3108581046465
# Iteration 2351: Switched package 2 of truck 11 trip 3 with package 1 of truck 19 trip 1, old cost: 597.3108581046465, new cost: 590.9660305184395
# Iteration 2358: Switched package 2 of truck 6 trip 1 with package 3 of truck 37 trip 2, old cost: 491.9243638517729, new cost: 491.84956737958834
# Iteration 2381: Switched package 3 of truck 3 trip 1 with package 1 of truck 28 trip 2, old cost: 491.84956737958834, new cost: 489.3352816653026
# Iteration 2421: Switched package 3 of truck 3 trip 2 with package 1 of truck 28 trip 1, old cost: 489.3352816653026, new cost: 486.7845570276215
# Iteration 2470: Switched package 1 of truck 35 trip 3 with package 3 of truck 36 trip 1, old cost: 486.7845570276215, new cost: 482.16270828812566
# Iteration 2607: Switched package 3 of truck 25 trip 3 with package 1 of truck 10 trip 1, old cost: 482.16270828812566, new cost: 481.91460702230285
# Iteration 2611: Switched package 3 of truck 34 trip 3 with package 2 of truck 2 trip 2, old cost: 481.91460702230285, new cost: 481.7817768336236
# Iteration 2620: Switched package 3 of truck 3 trip 2 with package 1 of truck 18 trip 3, old cost: 481.7817768336236, new cost: 481.6343928984725
# Iteration 2624: Switched package 2 of truck 1 trip 3 with package 1 of truck 32 trip 2, old cost: 481.6343928984725, new cost: 481.5666975276413
# Iteration 2628: Switched package 3 of truck 30 trip 2 with package 1 of truck 23 trip 3, old cost: 481.5666975276413, new cost: 479.18208214302587
# Iteration 2683: Switched package 3 of truck 3 trip 1 with package 1 of truck 24 trip 3, old cost: 379.9715558272364, new cost: 379.6173185391008
# Optimized cost: 379.9715558272364
#
# Truck deliveries after optimization:
# Truck 0:
#   Trip 1: weight = 828, package weights = [727]
#   Trip 2: weight = 828, package weights = [725]
#   Trip 3: weight = 828, package weights = [787]
# Truck 1:
#   Trip 1: weight = 702, package weights = [454]
#   Trip 2: weight = 702, package weights = [453]
# Truck 2:
#   Trip 1: weight = 747, package weights = [737]
#   Trip 2: weight = 747, package weights = [735]
#   Trip 3: weight = 747, package weights = [667]
# Truck 3:
#   Trip 1: weight = 564, package weights = [473]
#   Trip 2: weight = 564, package weights = [237, 313]
#   Trip 3: weight = 564, package weights = [285, 271]
# Truck 4:
#   Trip 1: weight = 702, package weights = [507]
#   Trip 2: weight = 702, package weights = [454]
#   Trip 3: weight = 702, package weights = [541]
# Truck 5:
#   Trip 1: weight = 660, package weights = [240]
#   Trip 2: weight = 660, package weights = [406, 234]
#   Trip 3: weight = 660, package weights = [249]
# Truck 6:
#   Trip 1: weight = 913, package weights = [891]
#   Trip 2: weight = 913, package weights = [912]
# Truck 7:
#   Trip 1: weight = 632, package weights = [466]
#   Trip 2: weight = 632, package weights = [463]
#   Trip 3: weight = 632, package weights = [353, 238]
# Truck 8:
#   Trip 1: weight = 677, package weights = [636]
#   Trip 2: weight = 677, package weights = [305, 247]
#   Trip 3: weight = 677, package weights = [478]
# Truck 9:
#   Trip 1: weight = 692, package weights = [688]
#   Trip 2: weight = 692, package weights = [273]
# Truck 10:
#   Trip 1: weight = 765, package weights = [594]
#   Trip 2: weight = 765, package weights = [709]
#   Trip 3: weight = 765, package weights = [674]
# Truck 11:
#   Trip 1: weight = 559, package weights = [442]
#   Trip 2: weight = 559, package weights = [528]
#   Trip 3: weight = 559, package weights = [507]
# Truck 12:
#   Trip 1: weight = 704, package weights = [575]
#   Trip 2: weight = 704, package weights = [668]
#   Trip 3: weight = 704, package weights = [619]
# Truck 13:
#   Trip 1: weight = 654, package weights = [624]
#   Trip 2: weight = 654, package weights = [605]
#   Trip 3: weight = 654, package weights = [473]
# Truck 14:
#   Trip 1: weight = 571, package weights = [461]
#   Trip 2: weight = 571, package weights = [525]
#   Trip 3: weight = 571, package weights = [462]
# Truck 15:
#   Trip 1: weight = 655, package weights = [587]
#   Trip 2: weight = 655, package weights = [518]
#   Trip 3: weight = 655, package weights = [370]
# Truck 16:
#   Trip 1: weight = 672, package weights = [271]
#   Trip 2: weight = 672, package weights = [629]
# Truck 17:
#   Trip 1: weight = 807, package weights = [803]
#   Trip 2: weight = 807, package weights = [695]
#   Trip 3: weight = 807, package weights = [728]
# Truck 18:
#   Trip 1: weight = 949, package weights = [926]
#   Trip 2: weight = 949, package weights = [835]
#   Trip 3: weight = 949, package weights = [926]
# Truck 19:
#   Trip 1: weight = 561, package weights = [460]
#   Trip 2: weight = 561, package weights = [492]
#   Trip 3: weight = 561, package weights = [445]
# Truck 20:
#   Trip 1: weight = 872, package weights = [837]
#   Trip 2: weight = 872, package weights = [872]
#   Trip 3: weight = 872, package weights = [750]
# Truck 21:
#   Trip 1: weight = 959, package weights = [917]
#   Trip 2: weight = 959, package weights = [923]
#   Trip 3: weight = 959, package weights = [866]
# Truck 22:
#   Trip 1: weight = 974, package weights = [749]
#   Trip 2: weight = 974, package weights = [897]
#   Trip 3: weight = 974, package weights = [944]
# Truck 23:
#   Trip 1: weight = 880, package weights = [861]
#   Trip 2: weight = 880, package weights = [798]
#   Trip 3: weight = 880, package weights = [747]
# Truck 24:
#   Trip 1: weight = 704, package weights = [686]
#   Trip 2: weight = 704, package weights = [641]
# Truck 25:
#   Trip 1: weight = 559, package weights = [310]
#   Trip 2: weight = 559, package weights = [283]
#   Trip 3: weight = 559, package weights = [416]
# Truck 26:
#   Trip 1: weight = 585, package weights = [312, 256]
#   Trip 2: weight = 585, package weights = [373]
# Truck 27:
#   Trip 1: weight = 923, package weights = [883]
# Truck 28:
#   Trip 1: weight = 642, package weights = [281]
#   Trip 2: weight = 642, package weights = [312]
#   Trip 3: weight = 642, package weights = [601]
# Truck 29:
#   Trip 1: weight = 850, package weights = [830]
#   Trip 2: weight = 850, package weights = [770]
#   Trip 3: weight = 850, package weights = [795]
# Truck 30:
#   Trip 1: weight = 506, package weights = [492]
#   Trip 2: weight = 506, package weights = [407]
#   Trip 3: weight = 506, package weights = [384]
# Truck 31:
#   Trip 1: weight = 794, package weights = [794]
#   Trip 2: weight = 794, package weights = [680]
#   Trip 3: weight = 794, package weights = [774]
# Truck 32:
#   Trip 1: weight = 996, package weights = [948]
#   Trip 2: weight = 996, package weights = [950]
#   Trip 3: weight = 996, package weights = [938]
# Truck 33:
#   Trip 1: weight = 678, package weights = [379]
#   Trip 2: weight = 678, package weights = [625]
# Truck 34:
#   Trip 1: weight = 726, package weights = [683]
#   Trip 2: weight = 726, package weights = [623]
#   Trip 3: weight = 726, package weights = [371]
# Truck 35:
#   Trip 1: weight = 506, package weights = [414]
#   Trip 2: weight = 506, package weights = [266, 216]
#   Trip 3: weight = 506, package weights = [483]
# Truck 36:
#   Trip 1: weight = 639, package weights = [469]
#   Trip 2: weight = 639, package weights = [296]
#   Trip 3: weight = 639, package weights = [223]
# Truck 37:
#   Trip 1: weight = 513, package weights = [234, 273]
#   Trip 2: weight = 513, package weights = [273]
#   Trip 3: weight = 513, package weights = [307]
# Truck 38:
#   Trip 1: weight = 533, package weights = [377]
#   Trip 2: weight = 533, package weights = [237, 224]
#   Trip 3: weight = 533, package weights = [479]
# Truck 39:
#   Trip 1: weight = 877, package weights = [874]
#   Trip 2: weight = 877, package weights = [821]
#   Trip 3: weight = 877, package weights = [859]
#
# Unassigned packages' weights: []
