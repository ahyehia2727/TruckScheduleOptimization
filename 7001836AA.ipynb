# %%
import numpy as np
import random
import math
import copy

# Task 1: Generate 40 trucks with capacity between 500 to 1000Kg
trucks_capacity = np.random.randint(500, 1001, size=40)

# Task 2: Generate 120 packages with weight (between 200-1000) and distance (between 20 to 100)
packages = np.random.randint(200, 1001, size=(120, 2))
packages[:, 1] = np.random.randint(20, 101, size=120)

# Task 3: Initial assignment
def initial_assignment(trucks_capacity, packages):
    assignments = np.full((40, 3), -1, dtype=int)

    package_assigned = np.zeros(len(packages), dtype=bool)
    for t_idx, capacity in enumerate(trucks_capacity):
        for i in range(3):  # A truck can carry up to 3 packages
            # Find packages that can be carried by the current truck and are not yet assigned
            available_packages = np.argwhere((packages[:, 0] <= capacity) & (~package_assigned)).flatten()
            if len(available_packages) > 0:
                p_idx = np.random.choice(available_packages)
                assignments[t_idx][i] = p_idx
                package_assigned[p_idx] = True
            else:
                break

    return assignments, package_assigned

# Task 4: Calculate the cost
def calculate_cost(assignments, initial_capacity, packages):
    cost = 0
    delivered_packages = np.zeros(len(packages), dtype=bool)
    for t_idx, deliveries in enumerate(assignments):
        for p_idx in deliveries:
            if p_idx != -1:
                p = packages[p_idx]
                cost += (initial_capacity[t_idx] - p[0]) / p[1]
                delivered_packages[p_idx] = True

    # Add penalty for undelivered packages
    penalty = 100 * np.sum(np.logical_not(delivered_packages))
    cost += penalty

    return cost, delivered_packages

# Task 5 and 6: Use SGA optimization
def sga_optimization(assignments, trucks_capacity, packages, initial_cost, max_iter=7500, tol=0.5):
    initial_capacity = trucks_capacity.copy()
    current_cost = initial_cost
    current_assignments = copy.deepcopy(assignments)

    for iteration in range(max_iter):
        # Swap two random packages
        t1, t2 = random.sample(range(40), 2)
        p1, p2 = random.sample(range(3), 2)
        new_assignments = copy.deepcopy(current_assignments)
        new_assignments[t1][p1], new_assignments[t2][p2] = new_assignments[t2][p2], new_assignments[t1][p1]

        # Check if the swap exceeds the truck capacity
        p1_weight = packages[new_assignments[t1][p1]][0] if new_assignments[t1][p1] != -1 else 0
        p2_weight = packages[new_assignments[t2][p2]][0] if new_assignments[t2][p2] != -1 else 0
        if p1_weight > initial_capacity[t1] or p2_weight > initial_capacity[t2]:
            continue

        # Calculate new cost
        new_cost, delivered_packages = calculate_cost(new_assignments, initial_capacity, packages)

        # Check if the cost is better
        if new_cost < current_cost:
            print(f"Iteration {iteration}: Switched package {p1} of truck {t1} with package {p2} of truck {t2}, old cost: {current_cost}, new cost: {new_cost}")
            # Check for convergence
            if abs(new_cost - current_cost) < tol and np.all(delivered_packages):
                break
            current_assignments, current_cost = new_assignments, new_cost

        # Assign unassigned packages
        unassigned_packages = np.argwhere(delivered_packages == False).flatten()
        for p_idx in unassigned_packages:
            p_weight = packages[p_idx][0]
            available_trucks = np.argwhere(initial_capacity >= p_weight).flatten()
            if len(available_trucks) > 0:
                t_idx = np.random.choice(available_trucks)
                for i, delivery in enumerate(current_assignments[t_idx]):
                    if delivery == -1:
                        current_assignments[t_idx][i] = p_idx
                        delivered_packages[p_idx] = True

                        # Recalculate the cost after assigning the package
                        current_cost, _ = calculate_cost(current_assignments, initial_capacity, packages)
                        break

        # Update truck capacities
        for t_idx in range(40):
            assigned_packages = current_assignments[t_idx]
            assigned_weights = np.array([packages[p_idx][0] if p_idx != -1 else 0 for p_idx in assigned_packages])

    return current_assignments, current_cost, initial_capacity

# Run the optimization
assignments, remaining_capacity = initial_assignment(trucks_capacity, packages)
initial_cost, _ = calculate_cost(assignments, trucks_capacity, packages)
print("Initial cost:", initial_cost)

optimized_assignments, optimized_cost,initial_capacity = sga_optimization(assignments, trucks_capacity, packages, initial_cost)
print("Optimized cost:", optimized_cost)

# Print truck deliveries
print("\nTruck deliveries after optimization:")

for truck_idx, assigned_packages in enumerate(optimized_assignments):
    truck_weight = initial_capacity[truck_idx]
    assigned_weights = [packages[p_idx][0] if p_idx != -1 else 0 for p_idx in assigned_packages]

    print(f"Truck {truck_idx}: weight = {truck_weight}, package weights = {assigned_weights}")

# Find and print unassigned packages' weights
_, delivered_packages = calculate_cost(optimized_assignments, initial_capacity, packages)
unassigned_packages = np.argwhere(delivered_packages == False).flatten()
unassigned_weights = [packages[p_idx][0] for p_idx in unassigned_packages]
print("\nUnassigned packages' weights:", unassigned_weights)
# Out:
# Initial cost: 1777.3544116080152
# Iteration 2: Switched package 2 of truck 8 with package 1 of truck 35, old cost: 1777.3544116080152, new cost: 1776.0802180596281
# Iteration 4: Switched package 1 of truck 7 with package 0 of truck 39, old cost: 1776.0802180596281, new cost: 1775.143205072615
# Iteration 9: Switched package 2 of truck 12 with package 0 of truck 20, old cost: 1775.143205072615, new cost: 1774.6223717392818
# Iteration 10: Switched package 2 of truck 13 with package 1 of truck 4, old cost: 1774.6223717392818, new cost: 1771.143583860494
# Iteration 15: Switched package 1 of truck 29 with package 2 of truck 8, old cost: 1771.143583860494, new cost: 1766.9150124319226
# Iteration 18: Switched package 2 of truck 12 with package 0 of truck 9, old cost: 1668.061353895337, new cost: 1667.61145871714
# Iteration 20: Switched package 0 of truck 25 with package 1 of truck 23, old cost: 1667.61145871714, new cost: 1666.9673909205299
# Iteration 26: Switched package 2 of truck 35 with package 0 of truck 17, old cost: 1666.9673909205299, new cost: 1660.6570460929436
# Iteration 30: Switched package 1 of truck 19 with package 2 of truck 4, old cost: 1660.6570460929436, new cost: 1660.6397565740433
# Iteration 41: Switched package 1 of truck 33 with package 2 of truck 5, old cost: 1561.1892071234938, new cost: 1558.5262857751793
# Iteration 45: Switched package 2 of truck 21 with package 0 of truck 12, old cost: 1460.6614209103143, new cost: 1459.7756184411785
# Iteration 47: Switched package 1 of truck 33 with package 2 of truck 21, old cost: 1459.7756184411785, new cost: 1459.645281362527
# Iteration 48: Switched package 2 of truck 28 with package 1 of truck 20, old cost: 1459.645281362527, new cost: 1454.7643289815744
# Iteration 52: Switched package 2 of truck 13 with package 1 of truck 38, old cost: 1454.7643289815744, new cost: 1451.8097835270291
# Iteration 57: Switched package 1 of truck 23 with package 2 of truck 14, old cost: 1451.8097835270291, new cost: 1450.0139072383693
# Iteration 62: Switched package 2 of truck 35 with package 1 of truck 33, old cost: 1450.0139072383693, new cost: 1449.6041371234267
# Iteration 68: Switched package 2 of truck 3 with package 0 of truck 13, old cost: 1449.6041371234267, new cost: 1448.458076517366
# Iteration 80: Switched package 1 of truck 37 with package 2 of truck 1, old cost: 1448.458076517366, new cost: 1448.361878624558
# Iteration 81: Switched package 2 of truck 21 with package 1 of truck 16, old cost: 1448.361878624558, new cost: 1447.8060733811124
# Iteration 83: Switched package 1 of truck 38 with package 2 of truck 34, old cost: 1447.8060733811124, new cost: 1445.9424370174759
# Iteration 88: Switched package 1 of truck 5 with package 2 of truck 33, old cost: 1445.9424370174759, new cost: 1442.5076544087801
# Iteration 91: Switched package 2 of truck 35 with package 0 of truck 0, old cost: 1442.5076544087801, new cost: 1442.4357794087803
# Iteration 92: Switched package 0 of truck 22 with package 1 of truck 7, old cost: 1442.4357794087803, new cost: 1442.3976189391128
# Iteration 102: Switched package 1 of truck 33 with package 0 of truck 34, old cost: 1442.3976189391128, new cost: 1435.3976189391128
# Iteration 115: Switched package 2 of truck 15 with package 1 of truck 35, old cost: 1336.0239925654864, new cost: 1335.973501681896
# Iteration 119: Switched package 1 of truck 6 with package 0 of truck 33, old cost: 1236.269420049243, new cost: 1233.769420049243
# Iteration 121: Switched package 2 of truck 10 with package 0 of truck 22, old cost: 1233.769420049243, new cost: 1233.7267392732288
# Iteration 122: Switched package 1 of truck 34 with package 0 of truck 8, old cost: 1233.7267392732288, new cost: 1229.713581378492
# Iteration 125: Switched package 1 of truck 0 with package 2 of truck 23, old cost: 1229.713581378492, new cost: 1229.5918063526922
# Iteration 130: Switched package 2 of truck 25 with package 1 of truck 4, old cost: 1229.5918063526922, new cost: 1225.5118063526922
# Iteration 132: Switched package 1 of truck 34 with package 0 of truck 2, old cost: 1225.5118063526922, new cost: 1223.1090603572688
# Iteration 136: Switched package 0 of truck 33 with package 2 of truck 28, old cost: 1223.1090603572688, new cost: 1222.3188817858404
# Iteration 145: Switched package 0 of truck 15 with package 2 of truck 12, old cost: 1222.3188817858404, new cost: 1221.1940059169228
# Iteration 149: Switched package 2 of truck 23 with package 0 of truck 28, old cost: 1221.1940059169228, new cost: 1220.3096921914325
# Iteration 150: Switched package 0 of truck 39 with package 1 of truck 31, old cost: 1220.3096921914325, new cost: 1219.668133749874
# Iteration 153: Switched package 2 of truck 26 with package 1 of truck 0, old cost: 1219.668133749874, new cost: 1219.3035005760303
# Iteration 161: Switched package 2 of truck 20 with package 1 of truck 25, old cost: 1219.3035005760303, new cost: 1218.5477650834528
# Iteration 162: Switched package 2 of truck 33 with package 0 of truck 20, old cost: 1218.5477650834528, new cost: 1218.2568230544673
# Iteration 164: Switched package 0 of truck 29 with package 1 of truck 6, old cost: 1218.2568230544673, new cost: 1218.150440075744
# Iteration 182: Switched package 2 of truck 24 with package 1 of truck 15, old cost: 1120.041349166653, new cost: 1119.5958806566682
# Iteration 183: Switched package 1 of truck 31 with package 0 of truck 14, old cost: 1119.5958806566682, new cost: 1119.361115421903
# Iteration 185: Switched package 0 of truck 14 with package 2 of truck 11, old cost: 1119.361115421903, new cost: 1117.6802853823774
# Iteration 192: Switched package 2 of truck 0 with package 1 of truck 3, old cost: 1117.6802853823774, new cost: 1117.1311986243863
# Iteration 195: Switched package 1 of truck 37 with package 2 of truck 28, old cost: 1117.1311986243863, new cost: 1116.4808607865486
# Iteration 197: Switched package 1 of truck 22 with package 0 of truck 24, old cost: 1116.4808607865486, new cost: 1115.6429297520658
# Iteration 208: Switched package 0 of truck 27 with package 1 of truck 33, old cost: 1115.6429297520658, new cost: 1115.1497790671342
# Iteration 233: Switched package 1 of truck 38 with package 2 of truck 24, old cost: 1115.1497790671342, new cost: 1110.60139197036
# Iteration 235: Switched package 0 of truck 6 with package 1 of truck 29, old cost: 1110.60139197036, new cost: 1110.5024170675676
# Iteration 239: Switched package 2 of truck 14 with package 1 of truck 10, old cost: 1110.5024170675676, new cost: 1107.2950860251851
# Iteration 248: Switched package 1 of truck 2 with package 0 of truck 27, old cost: 1107.2950860251851, new cost: 1106.5066244867235
# Iteration 256: Switched package 1 of truck 38 with package 2 of truck 34, old cost: 1106.5066244867235, new cost: 1104.402518914876
# Iteration 261: Switched package 1 of truck 24 with package 2 of truck 2, old cost: 1104.402518914876, new cost: 1104.2564319583541
# Iteration 269: Switched package 2 of truck 17 with package 0 of truck 6, old cost: 1104.2564319583541, new cost: 1103.9128779513856
# Iteration 272: Switched package 0 of truck 15 with package 2 of truck 38, old cost: 1103.9128779513856, new cost: 1101.7996704042157
# Iteration 278: Switched package 2 of truck 6 with package 1 of truck 0, old cost: 1101.7996704042157, new cost: 1101.4294172396587
# Iteration 281: Switched package 0 of truck 11 with package 2 of truck 4, old cost: 1101.4294172396587, new cost: 1101.0094752293494
# Iteration 293: Switched package 0 of truck 18 with package 1 of truck 12, old cost: 1101.0094752293494, new cost: 1094.2967423100947
# Iteration 295: Switched package 1 of truck 37 with package 2 of truck 16, old cost: 1094.2967423100947, new cost: 1094.2697815257811
# Iteration 296: Switched package 2 of truck 6 with package 0 of truck 1, old cost: 1094.2697815257811, new cost: 1094.2376669012751
# Iteration 316: Switched package 1 of truck 5 with package 2 of truck 1, old cost: 1094.2376669012751, new cost: 1094.2138263350616
# Iteration 337: Switched package 2 of truck 38 with package 0 of truck 27, old cost: 1094.2138263350616, new cost: 1094.1717363495754
# Iteration 338: Switched package 2 of truck 5 with package 1 of truck 17, old cost: 1094.1717363495754, new cost: 1094.0691439612688
# Iteration 340: Switched package 0 of truck 0 with package 1 of truck 38, old cost: 1094.0691439612688, new cost: 1094.0176288097537
# Iteration 345: Switched package 0 of truck 8 with package 1 of truck 6, old cost: 1094.0176288097537, new cost: 1092.5495437033708
# Iteration 350: Switched package 0 of truck 33 with package 1 of truck 18, old cost: 1092.5495437033708, new cost: 1092.1815509366438
# Iteration 353: Switched package 1 of truck 17 with package 0 of truck 30, old cost: 1092.1815509366438, new cost: 1092.1621469172396
# Iteration 354: Switched package 0 of truck 28 with package 2 of truck 35, old cost: 1092.1621469172396, new cost: 1092.0187645642986
# Iteration 360: Switched package 1 of truck 29 with package 0 of truck 8, old cost: 1092.0187645642986, new cost: 1091.448305113173
# Iteration 364: Switched package 1 of truck 22 with package 0 of truck 38, old cost: 1091.448305113173, new cost: 1084.7241671821384
# Iteration 366: Switched package 2 of truck 2 with package 0 of truck 11, old cost: 1084.7241671821384, new cost: 1084.7112805842003
# Iteration 390: Switched package 0 of truck 0 with package 2 of truck 20, old cost: 1084.7112805842003, new cost: 1084.4781803511
# Iteration 392: Switched package 2 of truck 13 with package 0 of truck 1, old cost: 1084.4781803511, new cost: 1084.3320764549962
# Iteration 398: Switched package 1 of truck 16 with package 0 of truck 17, old cost: 1084.3320764549962, new cost: 1084.3115800974213
# Iteration 409: Switched package 2 of truck 2 with package 0 of truck 8, old cost: 1084.3115800974213, new cost: 1084.2069932156046
# Iteration 412: Switched package 0 of truck 20 with package 2 of truck 4, old cost: 1084.2069932156046, new cost: 1084.0699914040101
# Iteration 414: Switched package 2 of truck 7 with package 0 of truck 29, old cost: 1084.0699914040101, new cost: 1083.842040250686
# Iteration 416: Switched package 2 of truck 28 with package 0 of truck 39, old cost: 1083.842040250686, new cost: 1083.834318242964
# Iteration 423: Switched package 0 of truck 9 with package 2 of truck 5, old cost: 1083.834318242964, new cost: 1083.788966769041
# Iteration 424: Switched package 2 of truck 0 with package 0 of truck 25, old cost: 1083.788966769041, new cost: 1082.099701232318
# Iteration 426: Switched package 0 of truck 9 with package 1 of truck 2, old cost: 1082.099701232318, new cost: 1079.956844089461
# Iteration 430: Switched package 0 of truck 3 with package 1 of truck 28, old cost: 980.3799210125377, new cost: 979.665231747001
# Iteration 449: Switched package 0 of truck 30 with package 1 of truck 7, old cost: 979.665231747001, new cost: 979.6648615137542
# Iteration 461: Switched package 1 of truck 19 with package 2 of truck 5, old cost: 979.6648615137542, new cost: 979.3711115137542
# Iteration 480: Switched package 1 of truck 18 with package 2 of truck 0, old cost: 979.3711115137542, new cost: 979.2819266872812
# Iteration 486: Switched package 1 of truck 10 with package 0 of truck 15, old cost: 979.2819266872812, new cost: 978.6530607078996
# Iteration 494: Switched package 2 of truck 2 with package 1 of truck 3, old cost: 978.6530607078996, new cost: 978.5863543350588
# Iteration 503: Switched package 1 of truck 18 with package 0 of truck 21, old cost: 978.5863543350588, new cost: 976.9615469390649
# Iteration 505: Switched package 0 of truck 29 with package 1 of truck 39, old cost: 976.9615469390649, new cost: 974.2600544017514
# Iteration 506: Switched package 0 of truck 0 with package 2 of truck 12, old cost: 974.2600544017514, new cost: 974.1672743747608
# Iteration 520: Switched package 0 of truck 0 with package 1 of truck 39, old cost: 974.1672743747608, new cost: 973.96401435905
# Iteration 521: Switched package 1 of truck 23 with package 0 of truck 38, old cost: 973.96401435905, new cost: 973.935278726866
# Iteration 537: Switched package 2 of truck 26 with package 1 of truck 14, old cost: 973.935278726866, new cost: 973.7118630448037
# Iteration 555: Switched package 1 of truck 18 with package 2 of truck 25, old cost: 973.7118630448037, new cost: 972.7900448629857
# Iteration 562: Switched package 2 of truck 39 with package 1 of truck 13, old cost: 972.7900448629857, new cost: 972.1847817050909
# Iteration 565: Switched package 2 of truck 14 with package 1 of truck 38, old cost: 972.1847817050909, new cost: 971.1051520754613
# Iteration 572: Switched package 0 of truck 27 with package 2 of truck 15, old cost: 971.1051520754613, new cost: 971.0941965063803
# Iteration 586: Switched package 2 of truck 1 with package 1 of truck 36, old cost: 971.0941965063803, new cost: 971.0854968726808
# Iteration 587: Switched package 1 of truck 12 with package 0 of truck 11, old cost: 971.0854968726808, new cost: 969.8626707857243
# Iteration 596: Switched package 2 of truck 23 with package 0 of truck 20, old cost: 969.8626707857243, new cost: 969.4782957857242
# Iteration 597: Switched package 2 of truck 13 with package 0 of truck 15, old cost: 969.4782957857242, new cost: 969.3907840706352
# Iteration 606: Switched package 1 of truck 28 with package 2 of truck 4, old cost: 969.3907840706352, new cost: 969.1844465614236
# Iteration 619: Switched package 1 of truck 8 with package 2 of truck 10, old cost: 969.1844465614236, new cost: 969.1578455762019
# Iteration 622: Switched package 2 of truck 24 with package 0 of truck 22, old cost: 969.1578455762019, new cost: 968.4911789095353
# Iteration 643: Switched package 2 of truck 20 with package 0 of truck 19, old cost: 968.4911789095353, new cost: 968.4648284484022
# Iteration 646: Switched package 2 of truck 23 with package 0 of truck 21, old cost: 968.4648284484022, new cost: 968.294012770436
# Iteration 650: Switched package 0 of truck 5 with package 1 of truck 13, old cost: 968.294012770436, new cost: 965.6418388573925
# Iteration 651: Switched package 0 of truck 19 with package 2 of truck 11, old cost: 965.6418388573925, new cost: 963.8236570392107
# Iteration 654: Switched package 0 of truck 18 with package 1 of truck 23, old cost: 963.8236570392107, new cost: 963.1759808772917
# Iteration 668: Switched package 1 of truck 31 with package 0 of truck 11, old cost: 963.1759808772917, new cost: 962.7570248333357
# Iteration 672: Switched package 1 of truck 2 with package 2 of truck 13, old cost: 962.7570248333357, new cost: 962.7530273580569
# Iteration 673: Switched package 0 of truck 13 with package 2 of truck 24, old cost: 962.7530273580569, new cost: 962.6996940247236
# Iteration 676: Switched package 0 of truck 17 with package 1 of truck 37, old cost: 962.6996940247236, new cost: 962.6663827226746
# Iteration 691: Switched package 0 of truck 13 with package 1 of truck 7, old cost: 962.6663827226746, new cost: 962.5904734800988
# Iteration 696: Switched package 0 of truck 23 with package 1 of truck 38, old cost: 962.5904734800988, new cost: 962.3055731951983
# Iteration 713: Switched package 0 of truck 18 with package 1 of truck 38, old cost: 962.3055731951983, new cost: 961.8900117451542
# Iteration 715: Switched package 0 of truck 33 with package 2 of truck 15, old cost: 961.8900117451542, new cost: 961.6913014513877
# Iteration 718: Switched package 1 of truck 7 with package 0 of truck 22, old cost: 961.6913014513877, new cost: 960.8888323155852
# Iteration 734: Switched package 1 of truck 23 with package 0 of truck 25, old cost: 960.8888323155852, new cost: 959.3658854556819
# Iteration 737: Switched package 0 of truck 14 with package 2 of truck 0, old cost: 959.3658854556819, new cost: 958.9921794515411
# Iteration 762: Switched package 1 of truck 26 with package 0 of truck 14, old cost: 958.9921794515411, new cost: 958.9077638671256
# Iteration 785: Switched package 1 of truck 4 with package 0 of truck 33, old cost: 958.9077638671256, new cost: 958.8597945674774
# Iteration 786: Switched package 2 of truck 29 with package 1 of truck 11, old cost: 958.8597945674774, new cost: 957.7397945674772
# Iteration 790: Switched package 0 of truck 18 with package 1 of truck 26, old cost: 957.7397945674772, new cost: 957.6079264356092
# Iteration 792: Switched package 0 of truck 24 with package 1 of truck 33, old cost: 957.6079264356092, new cost: 955.3935428739653
# Iteration 804: Switched package 0 of truck 11 with package 2 of truck 29, old cost: 955.3935428739653, new cost: 954.7473890278116
# Iteration 808: Switched package 0 of truck 17 with package 1 of truck 7, old cost: 954.7473890278116, new cost: 954.4415066748703
# Iteration 820: Switched package 0 of truck 0 with package 2 of truck 14, old cost: 954.4415066748703, new cost: 954.4084220977559
# Iteration 836: Switched package 2 of truck 27 with package 0 of truck 15, old cost: 954.4084220977559, new cost: 954.3893605141782
# Iteration 851: Switched package 1 of truck 29 with package 0 of truck 32, old cost: 954.3893605141782, new cost: 954.3167541311994
# Iteration 854: Switched package 2 of truck 29 with package 0 of truck 8, old cost: 954.3167541311994, new cost: 954.2161537007021
# Iteration 856: Switched package 0 of truck 28 with package 1 of truck 19, old cost: 954.2161537007021, new cost: 953.1102509229244
# Iteration 866: Switched package 1 of truck 33 with package 0 of truck 31, old cost: 953.1102509229244, new cost: 952.8363378794461
# Iteration 886: Switched package 0 of truck 0 with package 2 of truck 18, old cost: 952.8363378794461, new cost: 952.7981025853285
# Iteration 895: Switched package 2 of truck 3 with package 1 of truck 34, old cost: 952.7981025853285, new cost: 952.6044266960005
# Iteration 896: Switched package 2 of truck 20 with package 1 of truck 24, old cost: 952.6044266960005, new cost: 951.4644266960004
# Iteration 902: Switched package 1 of truck 12 with package 2 of truck 37, old cost: 951.4644266960004, new cost: 951.2540480143734
# Iteration 916: Switched package 1 of truck 10 with package 2 of truck 36, old cost: 951.2540480143734, new cost: 949.4125845997394
# Iteration 927: Switched package 0 of truck 12 with package 2 of truck 1, old cost: 949.4125845997394, new cost: 949.3940660812209
# Iteration 946: Switched package 0 of truck 20 with package 2 of truck 19, old cost: 949.3940660812209, new cost: 949.3696758373184
# Iteration 959: Switched package 1 of truck 31 with package 2 of truck 35, old cost: 949.3696758373184, new cost: 949.317154828915
# Iteration 1002: Switched package 1 of truck 31 with package 2 of truck 23, old cost: 949.317154828915, new cost: 949.0566031506166
# Iteration 1038: Switched package 2 of truck 23 with package 1 of truck 18, old cost: 949.0566031506166, new cost: 947.588367856499
# Iteration 1043: Switched package 2 of truck 36 with package 1 of truck 29, old cost: 947.588367856499, new cost: 947.5133678564989
# Iteration 1054: Switched package 1 of truck 38 with package 0 of truck 4, old cost: 947.5133678564989, new cost: 947.3728825435999
# Iteration 1056: Switched package 1 of truck 2 with package 2 of truck 5, old cost: 947.3728825435999, new cost: 947.3557004130157
# Iteration 1061: Switched package 1 of truck 2 with package 2 of truck 8, old cost: 947.3557004130157, new cost: 946.9018313653967
# Iteration 1088: Switched package 2 of truck 12 with package 0 of truck 16, old cost: 946.9018313653967, new cost: 946.8139192774845
# Iteration 1107: Switched package 2 of truck 30 with package 0 of truck 7, old cost: 946.8139192774845, new cost: 946.8007227965461
# Iteration 1172: Switched package 2 of truck 30 with package 1 of truck 22, old cost: 946.8007227965461, new cost: 945.3689046147279
# Iteration 1175: Switched package 2 of truck 23 with package 0 of truck 34, old cost: 945.3689046147279, new cost: 944.8282149595555
# Iteration 1179: Switched package 2 of truck 6 with package 1 of truck 17, old cost: 944.8282149595555, new cost: 943.7858515258877
# Iteration 1202: Switched package 2 of truck 21 with package 0 of truck 27, old cost: 943.7858515258877, new cost: 943.7523031387909
# Iteration 1217: Switched package 2 of truck 26 with package 0 of truck 18, old cost: 943.7523031387909, new cost: 943.5074051796073
# Iteration 1220: Switched package 2 of truck 18 with package 0 of truck 4, old cost: 943.5074051796073, new cost: 943.3648764439752
# Iteration 1227: Switched package 1 of truck 7 with package 0 of truck 16, old cost: 943.3648764439752, new cost: 943.2497934877156
# Iteration 1248: Switched package 0 of truck 15 with package 1 of truck 27, old cost: 943.2497934877156, new cost: 943.2167486411381
# Iteration 1281: Switched package 2 of truck 15 with package 1 of truck 24, old cost: 943.2167486411381, new cost: 943.1635473936606
# Iteration 1285: Switched package 2 of truck 32 with package 1 of truck 5, old cost: 943.1635473936606, new cost: 942.9385203471406
# Iteration 1292: Switched package 1 of truck 32 with package 0 of truck 1, old cost: 942.9385203471406, new cost: 942.9334709046832
# Iteration 1307: Switched package 1 of truck 6 with package 2 of truck 29, old cost: 942.9334709046832, new cost: 942.830378121178
# Iteration 1310: Switched package 2 of truck 6 with package 0 of truck 17, old cost: 942.830378121178, new cost: 942.3944806852805
# Iteration 1350: Switched package 0 of truck 21 with package 1 of truck 0, old cost: 942.3944806852805, new cost: 942.1868066346476
# Iteration 1377: Switched package 1 of truck 32 with package 0 of truck 5, old cost: 942.1868066346476, new cost: 941.6561943897498
# Iteration 1393: Switched package 0 of truck 26 with package 2 of truck 19, old cost: 841.9327901344305, new cost: 839.9077901344306
# Iteration 1447: Switched package 0 of truck 20 with package 2 of truck 18, old cost: 839.9077901344306, new cost: 838.7673359712683
# Iteration 1455: Switched package 2 of truck 6 with package 1 of truck 16, old cost: 838.7673359712683, new cost: 838.2288744328067
# Iteration 1484: Switched package 2 of truck 13 with package 0 of truck 30, old cost: 739.6788744328067, new cost: 739.4587178770337
# Iteration 1496: Switched package 2 of truck 29 with package 0 of truck 16, old cost: 739.4587178770337, new cost: 738.9998943476219
# Iteration 1515: Switched package 2 of truck 26 with package 1 of truck 38, old cost: 639.2975133952409, new cost: 638.9668255645532
# Iteration 1525: Switched package 1 of truck 19 with package 2 of truck 18, old cost: 638.9668255645532, new cost: 637.62574324748
# Iteration 1533: Switched package 0 of truck 11 with package 1 of truck 28, old cost: 637.62574324748, new cost: 637.6247080507927
# Iteration 1562: Switched package 1 of truck 37 with package 0 of truck 5, old cost: 637.6247080507927, new cost: 637.5916881012398
# Iteration 1607: Switched package 1 of truck 31 with package 2 of truck 3, old cost: 637.5916881012398, new cost: 637.5916881012397
# Iteration 1639: Switched package 0 of truck 0 with package 1 of truck 31, old cost: 637.5916881012397, new cost: 637.5085678966361
# Iteration 1649: Switched package 0 of truck 3 with package 1 of truck 4, old cost: 637.5085678966361, new cost: 637.3481905381457
# Iteration 1652: Switched package 2 of truck 1 with package 1 of truck 10, old cost: 637.3481905381457, new cost: 637.3259080930989
# Iteration 1683: Switched package 2 of truck 6 with package 0 of truck 36, old cost: 637.3259080930989, new cost: 637.2587530259439
# Iteration 1693: Switched package 1 of truck 16 with package 0 of truck 37, old cost: 637.2587530259439, new cost: 636.7349435021343
# Iteration 1724: Switched package 1 of truck 5 with package 0 of truck 12, old cost: 636.7349435021343, new cost: 636.675841847288
# Iteration 1730: Switched package 2 of truck 5 with package 1 of truck 1, old cost: 636.675841847288, new cost: 636.665130908742
# Iteration 1738: Switched package 1 of truck 7 with package 0 of truck 22, old cost: 636.665130908742, new cost: 636.6342667112111
# Iteration 1742: Switched package 2 of truck 30 with package 0 of truck 32, old cost: 636.6342667112111, new cost: 635.4534156473812
# Iteration 1746: Switched package 0 of truck 34 with package 2 of truck 25, old cost: 535.7134156473812, new cost: 535.7079611019267
# Iteration 1748: Switched package 1 of truck 33 with package 0 of truck 2, old cost: 535.7079611019267, new cost: 535.531759728929
# Iteration 1753: Switched package 2 of truck 30 with package 0 of truck 17, old cost: 535.531759728929, new cost: 535.4706577103802
# Iteration 1777: Switched package 2 of truck 6 with package 0 of truck 5, old cost: 535.4706577103802, new cost: 535.4210322422155
# Iteration 1800: Switched package 2 of truck 26 with package 0 of truck 20, old cost: 535.4210322422155, new cost: 535.3163068271451
# Iteration 1832: Switched package 1 of truck 22 with package 0 of truck 10, old cost: 535.3163068271451, new cost: 535.2091639700022
# Iteration 1888: Switched package 1 of truck 36 with package 0 of truck 17, old cost: 535.2091639700022, new cost: 535.1958368715689
# Iteration 1901: Switched package 2 of truck 26 with package 1 of truck 19, old cost: 535.1958368715689, new cost: 534.3783431793905
# Iteration 1909: Switched package 0 of truck 20 with package 2 of truck 0, old cost: 534.3783431793905, new cost: 533.7342207961377
# Iteration 1916: Switched package 1 of truck 2 with package 0 of truck 39, old cost: 533.7342207961377, new cost: 533.6137574756744
# Iteration 1920: Switched package 2 of truck 19 with package 1 of truck 34, old cost: 533.6137574756744, new cost: 533.150121112038
# Iteration 1983: Switched package 0 of truck 6 with package 2 of truck 32, old cost: 533.150121112038, new cost: 533.0196126374617
# Iteration 1998: Switched package 0 of truck 30 with package 1 of truck 12, old cost: 533.0196126374617, new cost: 532.7174401555658
# Iteration 2006: Switched package 2 of truck 32 with package 0 of truck 29, old cost: 532.7174401555658, new cost: 532.1602972984228
# Iteration 2007: Switched package 2 of truck 19 with package 0 of truck 26, old cost: 532.1602972984228, new cost: 531.9762063893319
# Iteration 2053: Switched package 1 of truck 20 with package 0 of truck 19, old cost: 432.22065083377635, new cost: 431.2249798381054
# Iteration 2055: Switched package 2 of truck 21 with package 1 of truck 33, old cost: 431.2249798381054, new cost: 431.1536725375961
# Iteration 2094: Switched package 2 of truck 0 with package 1 of truck 20, old cost: 431.1536725375961, new cost: 429.7226961066196
# Iteration 2104: Switched package 2 of truck 11 with package 0 of truck 27, old cost: 429.7226961066196, new cost: 429.6899688338923
# Iteration 2128: Switched package 2 of truck 14 with package 1 of truck 4, old cost: 429.6899688338923, new cost: 429.6642640246055
# Iteration 2133: Switched package 2 of truck 38 with package 0 of truck 0, old cost: 429.6642640246055, new cost: 429.57897974366904
# Iteration 2147: Switched package 1 of truck 14 with package 2 of truck 18, old cost: 429.57897974366904, new cost: 429.5674665857743
# Iteration 2171: Switched package 0 of truck 13 with package 1 of truck 10, old cost: 429.5674665857743, new cost: 429.5417742267486
# Iteration 2188: Switched package 1 of truck 28 with package 2 of truck 27, old cost: 429.5417742267486, new cost: 429.47456643454086
# Iteration 2218: Switched package 1 of truck 2 with package 2 of truck 39, old cost: 429.47456643454086, new cost: 429.47172148432753
# Iteration 2220: Switched package 1 of truck 28 with package 0 of truck 22, old cost: 429.47172148432753, new cost: 429.3901364027424
# Iteration 2225: Switched package 0 of truck 6 with package 1 of truck 5, old cost: 429.3901364027424, new cost: 429.380955611782
# Iteration 2269: Switched package 2 of truck 4 with package 0 of truck 3, old cost: 429.380955611782, new cost: 429.34641771603526
# Iteration 2285: Switched package 2 of truck 30 with package 1 of truck 9, old cost: 429.34641771603526, new cost: 429.06693053654806
# Iteration 2305: Switched package 0 of truck 14 with package 1 of truck 0, old cost: 429.06693053654806, new cost: 428.93198735472987
# Iteration 2321: Switched package 1 of truck 39 with package 2 of truck 2, old cost: 428.93198735472987, new cost: 428.9276614715287
# Iteration 2322: Switched package 1 of truck 11 with package 2 of truck 27, old cost: 428.9276614715287, new cost: 428.8248043286716
# Iteration 2328: Switched package 1 of truck 39 with package 0 of truck 24, old cost: 428.8248043286716, new cost: 428.8248043286715
# Iteration 2341: Switched package 2 of truck 2 with package 0 of truck 28, old cost: 428.8248043286715, new cost: 428.78796222340833
# Iteration 2349: Switched package 0 of truck 17 with package 2 of truck 6, old cost: 428.78796222340833, new cost: 428.77956612512463
# Iteration 2365: Switched package 0 of truck 21 with package 1 of truck 28, old cost: 428.77956612512463, new cost: 428.77388615109015
# Iteration 2388: Switched package 2 of truck 10 with package 0 of truck 2, old cost: 428.77388615109015, new cost: 428.67193712560294
# Iteration 2390: Switched package 0 of truck 29 with package 2 of truck 36, old cost: 428.67193712560294, new cost: 428.6612228398887
# Iteration 2420: Switched package 0 of truck 17 with package 2 of truck 1, old cost: 428.6612228398887, new cost: 428.62765199856227
# Iteration 2508: Switched package 2 of truck 35 with package 1 of truck 4, old cost: 428.62765199856227, new cost: 428.48692705186716
# Iteration 2549: Switched package 0 of truck 6 with package 2 of truck 36, old cost: 428.48692705186716, new cost: 428.4853397502798
# Iteration 2555: Switched package 0 of truck 28 with package 2 of truck 24, old cost: 428.4853397502798, new cost: 428.4849888730868
# Iteration 2559: Switched package 2 of truck 24 with package 0 of truck 21, old cost: 428.4849888730868, new cost: 428.47250574218265
# Iteration 2587: Switched package 1 of truck 6 with package 2 of truck 37, old cost: 428.47250574218265, new cost: 428.4562574230433
# Iteration 2652: Switched package 0 of truck 27 with package 2 of truck 35, old cost: 428.4562574230433, new cost: 428.4533175768199
# Iteration 2674: Switched package 1 of truck 4 with package 0 of truck 14, old cost: 428.4533175768199, new cost: 428.44885329110565
# Iteration 2688: Switched package 2 of truck 1 with package 1 of truck 6, old cost: 428.44885329110565, new cost: 428.44848690126685
# Iteration 2714: Switched package 1 of truck 26 with package 2 of truck 20, old cost: 428.44848690126685, new cost: 428.21720484998474
# Iteration 2718: Switched package 1 of truck 8 with package 2 of truck 2, old cost: 428.21720484998474, new cost: 428.1378397706197
# Iteration 2806: Switched package 1 of truck 1 with package 2 of truck 36, old cost: 428.1378397706197, new cost: 428.1271009390046
# Iteration 2813: Switched package 1 of truck 20 with package 2 of truck 19, old cost: 428.1271009390046, new cost: 427.64561945752314
# Iteration 2818: Switched package 0 of truck 36 with package 1 of truck 12, old cost: 427.64561945752314, new cost: 427.6338455171777
# Iteration 2857: Switched package 0 of truck 33 with package 1 of truck 14, old cost: 427.6338455171777, new cost: 427.59809339853365
# Iteration 2882: Switched package 1 of truck 37 with package 2 of truck 16, old cost: 427.59809339853365, new cost: 427.5938416978534
# Iteration 2896: Switched package 2 of truck 4 with package 1 of truck 14, old cost: 427.5938416978534, new cost: 427.5900041538816
# Iteration 2912: Switched package 0 of truck 36 with package 1 of truck 9, old cost: 427.5900041538816, new cost: 427.4774976128036
# Iteration 2921: Switched package 2 of truck 10 with package 1 of truck 22, old cost: 427.4774976128036, new cost: 427.3237709047291
# Iteration 2934: Switched package 1 of truck 19 with package 2 of truck 34, old cost: 427.3237709047291, new cost: 427.28595110495155
# Iteration 2946: Switched package 2 of truck 33 with package 0 of truck 21, old cost: 427.28595110495155, new cost: 427.27016163126734
# Iteration 3019: Switched package 0 of truck 29 with package 2 of truck 36, old cost: 427.27016163126734, new cost: 427.25701730137047
# Iteration 3097: Switched package 2 of truck 39 with package 0 of truck 28, old cost: 427.25701730137047, new cost: 427.25521549956864
# Iteration 3120: Switched package 0 of truck 24 with package 1 of truck 28, old cost: 427.25521549956864, new cost: 427.2531346949909
# Iteration 3126: Switched package 1 of truck 4 with package 2 of truck 3, old cost: 427.2531346949909, new cost: 427.22929994922816
# Iteration 3136: Switched package 1 of truck 27 with package 2 of truck 21, old cost: 427.22929994922816, new cost: 427.19364629897353
# Iteration 3183: Switched package 2 of truck 8 with package 0 of truck 13, old cost: 427.19364629897353, new cost: 427.1685691384797
# Iteration 3190: Switched package 0 of truck 22 with package 2 of truck 13, old cost: 427.1685691384797, new cost: 427.16856913847965
# Iteration 3208: Switched package 0 of truck 17 with package 2 of truck 36, old cost: 427.16856913847965, new cost: 427.156983772626
# Iteration 3316: Switched package 1 of truck 39 with package 0 of truck 28, old cost: 427.156983772626, new cost: 427.1551326063913
# Iteration 3405: Switched package 1 of truck 26 with package 0 of truck 18, old cost: 427.1551326063913, new cost: 427.12574485128926
# Iteration 3446: Switched package 2 of truck 11 with package 0 of truck 21, old cost: 427.12574485128926, new cost: 427.1007448512893
# Iteration 3462: Switched package 2 of truck 9 with package 0 of truck 16, old cost: 427.1007448512893, new cost: 427.09755388418074
# Iteration 3501: Switched package 2 of truck 20 with package 1 of truck 23, old cost: 427.09755388418074, new cost: 427.0099470465739
# Iteration 3521: Switched package 1 of truck 32 with package 2 of truck 37, old cost: 427.0099470465739, new cost: 427.0033666561374
# Iteration 3524: Switched package 2 of truck 11 with package 1 of truck 28, old cost: 427.0033666561374, new cost: 426.99737350545246
# Iteration 3536: Switched package 0 of truck 21 with package 1 of truck 15, old cost: 426.99737350545246, new cost: 426.72308779116673
# Iteration 3586: Switched package 1 of truck 24 with package 2 of truck 39, old cost: 426.72308779116673, new cost: 426.7176869472849
# Iteration 3588: Switched package 2 of truck 27 with package 1 of truck 15, old cost: 426.7176869472849, new cost: 426.69102028061826
# Iteration 3619: Switched package 1 of truck 11 with package 2 of truck 27, old cost: 426.69102028061826, new cost: 426.6738774234754
# Iteration 3666: Switched package 1 of truck 24 with package 2 of truck 33, old cost: 426.6738774234754, new cost: 426.6631756690895
# Iteration 3733: Switched package 1 of truck 6 with package 0 of truck 13, old cost: 426.6631756690895, new cost: 426.5607646204004
# Iteration 3824: Switched package 2 of truck 13 with package 1 of truck 8, old cost: 426.5607646204004, new cost: 426.5574817921176
# Iteration 3942: Switched package 0 of truck 16 with package 1 of truck 29, old cost: 426.5574817921176, new cost: 426.15541993644746
# Iteration 3986: Switched package 0 of truck 23 with package 1 of truck 20, old cost: 326.2665310475586, new cost: 325.77301252904005
# Optimized cost: 326.2665310475586
#
# Truck deliveries after optimization:
# Truck 0: weight = 663, package weights = [615, 554, 496]
# Truck 1: weight = 950, package weights = [914, 917, 648]
# Truck 2: weight = 786, package weights = [786, 539, 773]
# Truck 3: weight = 702, package weights = [678, 495, 427]
# Truck 4: weight = 684, package weights = [510, 375, 443]
# Truck 5: weight = 946, package weights = [899, 898, 930]
# Truck 6: weight = 949, package weights = [902, 218, 889]
# Truck 7: weight = 889, package weights = [839, 759, 855]
# Truck 8: weight = 811, package weights = [558, 535, 425]
# Truck 9: weight = 996, package weights = [985, 722, 973]
# Truck 10: weight = 802, package weights = [790, 788, 800]
# Truck 11: weight = 763, package weights = [269, 562, 356]
# Truck 12: weight = 938, package weights = [901, 865, 831]
# Truck 13: weight = 824, package weights = [534, 819, 244]
# Truck 14: weight = 682, package weights = [529, 598, 675]
# Truck 15: weight = 741, package weights = [739, 740, 373]
# Truck 16: weight = 998, package weights = [995, 970, 795]
# Truck 17: weight = 915, package weights = [885, 905, 912]
# Truck 18: weight = 676, package weights = [372, 473, 273]
# Truck 19: weight = 523, package weights = [523, 275, 267]
# Truck 20: weight = 563, package weights = [535, 399, 258]
# Truck 21: weight = 733, package weights = [723, 726, 714]
# Truck 22: weight = 824, package weights = [822, 637, 804]
# Truck 23: weight = 604, package weights = [534, 475, 238]
# Truck 24: weight = 770, package weights = [448, 217, 362]
# Truck 25: weight = 507, package weights = [378, 479, 258]
# Truck 26: weight = 604, package weights = [440, 597, 494]
# Truck 27: weight = 745, package weights = [336, 361, 704]
# Truck 28: weight = 768, package weights = [681, 542, 523]
# Truck 29: weight = 959, package weights = [269, 894, 837]
# Truck 30: weight = 887, package weights = [882, 825, 838]
# Truck 31: weight = 702, package weights = [682, 655, 687]
# Truck 32: weight = 998, package weights = [972, 263, 987]
# Truck 33: weight = 709, package weights = [246, 559, 622]
# Truck 34: weight = 506, package weights = [361, 397, 347]
# Truck 35: weight = 732, package weights = [721, 730, 291]
# Truck 36: weight = 953, package weights = [881, 782, 791]
# Truck 37: weight = 978, package weights = [969, 468, 972]
# Truck 38: weight = 629, package weights = [586, 208, 256]
# Truck 39: weight = 778, package weights = [771, 713, 549]
#
# Unassigned packages' weights: []
